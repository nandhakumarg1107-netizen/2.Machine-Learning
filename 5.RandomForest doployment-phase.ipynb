# %%
import pickle

# %%
loaded_model=pickle.load(open("Final_model_RandomForest_Regression.sav",'rb'))
result=loaded_model.predict([[1901,1107,4769,0,0]])
# Out:
# C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([51115.5152])
