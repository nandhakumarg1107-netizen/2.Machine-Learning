# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[12]])
# Out:
# C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[139100.52677552]])
